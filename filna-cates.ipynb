# %%
import numpy as np
import pandas as pd
import twosigmafunc
import json

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
train, origin_features = twosigmafunc.preprocess()

# %%
try:
    with open('features.json', 'r') as js:
        features = json.load(js)
except IOError as err:
    raise err

# %%
train, origin_features = twosigmafunc.preprocess()

# %%
twosigmafunc.add_nans(train, origin_features)
# Out:
# sucessfully add 108 nan features

# %%
for col in features['t22_features']:
    train[col] = train[col].fillna(train.groupby('technical_22')[col].transform("median"))

# %%
for col in features['t34_features']:
    train[col] = train[col].fillna(train.groupby('technical_34')[col].transform("median"))

# %%
twosigmafunc.add_diffs(train, origin_features)
# Out:
# sucessfully add 108 diff features

# %% [markdown]
# # Add dummy features

# %%
t22_dummy = pd.get_dummies(train.technical_22, prefix='t22')
train = pd.concat([train, t22_dummy], axis=1)
t34_dummy = pd.get_dummies(train.technical_34, prefix='t34')
train = pd.concat([train, t34_dummy], axis=1)

# %%
train.drop(['technical_22', 'technical_34'], axis=1, inplace=True)

# %%
train.head()
# Out:
#         id  timestamp  derived_0  derived_1  derived_2  derived_3  derived_4  \
# 131062   0        167   0.002392  -0.024803   0.019819  -0.005069   0.016409
# 131895   0        168   0.002392  -0.024803   0.019819  -0.005069   0.016409
# 132728   0        169   0.002392  -0.024803   0.019819  -0.005069   0.016409
# 133561   0        170  -0.230583   0.488096   0.935920   0.028222  -0.083071
# 134393   0        171  -0.230583   0.488096   0.935920   0.028222  -0.083071
#
#         fundamental_0  fundamental_1  fundamental_2   ...     \
# 131062      -0.056218       0.003928       0.062897   ...
# 131895      -0.056218       0.003928       0.062897   ...
# 132728      -0.056218       0.003928       0.062897   ...
# 133561      -0.240929       0.003928       0.212425   ...
# 134393      -0.240929       0.003928       0.212425   ...
#
#         technical_41_diff  technical_42_diff  technical_43_diff  \
# 131062                0.0                0.0           0.000000
# 131895                0.0                0.0           0.000000
# 132728                0.0                0.0           0.000000
# 133561                0.0                0.0           0.027205
# 134393                0.0                0.0           0.000000
#
#         technical_44_diff  t22_-0.5  t22_0.0  t22_0.5  t34_-0.5  t34_0.0  \
# 131062                0.0         1        0        0         0        1
# 131895                0.0         1        0        0         0        1
# 132728                0.0         1        0        0         0        1
# 133561                0.0         1        0        0         0        1
# 134393                0.0         1        0        0         0        1
#
#         t34_0.5
# 131062        0
# 131895        0
# 132728        0
# 133561        0
# 134393        0
#
# [5 rows x 333 columns]

# %% [markdown]
# # Special features

# %%
train['tec20-30'] = train.technical_20 - train.technical_30
train['tec123'] = train['tec20-30'] + train.technical_13
train['y_past'] = train.y.shift()
train['tec123_past'] = train.tec123.shift()
train.loc[train.id_diff != 0, ['y_past', 'tec123_past']] = 0
train.fillna(0, inplace=True)

# %%
etr_features = twosigmafunc.origin_features(train)

# %%
etr_features.remove('id_diff')

# %%
len(etr_features)
# Out:
# 333

# %%
X_train, y_train, X_test, y_test = twosigmafunc.split_data(train, etr_features)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 806298 entries, 131062 to 806297
# Columns: 333 entries, derived_0 to tec123_past
# dtypes: float32(218), int64(109), uint8(6)
# memory usage: 1.3 GB

# %%
del train

# %% [markdown]
# # Train ETR

# %%
from sklearn.ensemble import ExtraTreesRegressor
etr = ExtraTreesRegressor(n_jobs=-1,n_estimators=80, max_depth=6, max_features='sqrt', min_samples_leaf=30,
                          random_state=17, verbose=0)

# %%
etr.fit(X_train, y_train)
# Out:
# ExtraTreesRegressor(bootstrap=False, criterion='mse', max_depth=6,
#           max_features='sqrt', max_leaf_nodes=None,
#           min_impurity_split=1e-07, min_samples_leaf=30,
#           min_samples_split=2, min_weight_fraction_leaf=0.0,
#           n_estimators=80, n_jobs=-1, oob_score=False, random_state=17,
#           verbose=0, warm_start=False)

# %%
pred = etr.predict(X_train)
twosigmafunc.R_score(pred, y_train)
# Out:
# 0.042337441721562362

# %%
pred = etr.predict(X_test)
twosigmafunc.R_score(pred, y_test)
# Out:
# 0.016598126624915416

# %%
imp = pd.DataFrame({'feature':etr_features, 'important':etr.feature_importances_}).sort_values('important', ascending=False)

# %%
features1 = list(imp.loc[imp.important > 0].feature)

# %%
etr.fit(X_train[features1], y_train)
# Out:
# ExtraTreesRegressor(bootstrap=False, criterion='mse', max_depth=6,
#           max_features='sqrt', max_leaf_nodes=None,
#           min_impurity_split=1e-07, min_samples_leaf=30,
#           min_samples_split=2, min_weight_fraction_leaf=0.0,
#           n_estimators=80, n_jobs=-1, oob_score=False, random_state=17,
#           verbose=0, warm_start=False)

# %%
pred = etr.predict(X_train[features1])
twosigmafunc.R_score(pred, y_train)
# Out:
# 0.044104738713101548

# %%
pred = etr.predict(X_test[features1])
twosigmafunc.R_score(pred, y_test)
# Out:
# 0.017932906038324991

# %%
imp = pd.DataFrame({'feature':features1, 'important':etr.feature_importances_}).sort_values('important', ascending=False)

# %%
features1 = list(imp.loc[imp.important > 0].feature)
etr.fit(X_train[features1], y_train)
# Out:
# ExtraTreesRegressor(bootstrap=False, criterion='mse', max_depth=6,
#           max_features='sqrt', max_leaf_nodes=None,
#           min_impurity_split=1e-07, min_samples_leaf=30,
#           min_samples_split=2, min_weight_fraction_leaf=0.0,
#           n_estimators=80, n_jobs=-1, oob_score=False, random_state=17,
#           verbose=0, warm_start=False)

# %%
pred = etr.predict(X_train[features1])
twosigmafunc.R_score(pred, y_train)
# Out:
# 0.043356456778671178

# %%
pred = etr.predict(X_test[features1])
twosigmafunc.R_score(pred, y_test)
# Out:
# 0.016418749782478134

# %%
imp = pd.DataFrame({'feature':features1, 'important':etr.feature_importances_}).sort_values('important', ascending=False)

# %%
features1 = list(imp.loc[imp.important > 0].feature)
etr = ExtraTreesRegressor(n_jobs=-1,n_estimators=100, max_depth=10, max_features='sqrt', min_samples_leaf=20,
                          random_state=17, verbose=0)
etr.fit(X_train[features1], y_train)
# Out:
# ExtraTreesRegressor(bootstrap=False, criterion='mse', max_depth=10,
#           max_features='sqrt', max_leaf_nodes=None,
#           min_impurity_split=1e-07, min_samples_leaf=20,
#           min_samples_split=2, min_weight_fraction_leaf=0.0,
#           n_estimators=100, n_jobs=-1, oob_score=False, random_state=17,
#           verbose=0, warm_start=False)

# %%
pred = etr.predict(X_train[features1])
twosigmafunc.R_score(pred, y_train)
# Out:
# 0.079430841062204285

# %%
pred = etr.predict(X_test[features1])
twosigmafunc.R_score(pred, y_test)
# Out:
# 0.0209048938469957

# %% [markdown]
# overfit, retrain...

# %%
etr = ExtraTreesRegressor(n_jobs=-1,n_estimators=100, max_depth=6, max_features='sqrt', min_samples_leaf=20,
                          random_state=17, verbose=0)
etr.fit(X_train[features1], y_train)
# Out:
# ExtraTreesRegressor(bootstrap=False, criterion='mse', max_depth=6,
#           max_features='sqrt', max_leaf_nodes=None,
#           min_impurity_split=1e-07, min_samples_leaf=20,
#           min_samples_split=2, min_weight_fraction_leaf=0.0,
#           n_estimators=100, n_jobs=-1, oob_score=False, random_state=17,
#           verbose=0, warm_start=False)

# %%
pred = etr.predict(X_train[features1])
twosigmafunc.R_score(pred, y_train)
# Out:
# 0.044592482252342129

# %%
pred = etr.predict(X_test[features1])
twosigmafunc.R_score(pred, y_test)
# Out:
# 0.017250228288929519

# %%
imp = pd.DataFrame({'feature':features1, 'important':etr.feature_importances_}).sort_values('important', ascending=False)

# %%
features1 = list(imp.loc[imp.important > 0.0005].feature)
len(features1)
# Out:
# 237

# %%
etr = ExtraTreesRegressor(n_jobs=-1,n_estimators=100, max_depth=5, max_features='sqrt', min_samples_leaf=30,
                          random_state=17, verbose=0)
etr.fit(X_train[features1], y_train)
# Out:
# ExtraTreesRegressor(bootstrap=False, criterion='mse', max_depth=5,
#           max_features='sqrt', max_leaf_nodes=None,
#           min_impurity_split=1e-07, min_samples_leaf=30,
#           min_samples_split=2, min_weight_fraction_leaf=0.0,
#           n_estimators=100, n_jobs=-1, oob_score=False, random_state=17,
#           verbose=0, warm_start=False)

# %%
pred = etr.predict(X_train[features1])
twosigmafunc.R_score(pred, y_train)
# Out:
# 0.037582525809880911

# %%
pred = etr.predict(X_test[features1])
twosigmafunc.R_score(pred, y_test)
# Out:
# 0.017641225492253196

# %%
imp = pd.DataFrame({'feature':features1, 'important':etr.feature_importances_}).sort_values('important', ascending=False)

# %%
features1 = list(imp.loc[imp.important > 0.0005].feature)
len(features1)
# Out:
# 203

# %%
etr = ExtraTreesRegressor(n_jobs=-1,n_estimators=100, max_depth=5, max_features='sqrt', min_samples_leaf=10,
                          random_state=17, verbose=0)
etr.fit(X_train[features1], y_train)
# Out:
# ExtraTreesRegressor(bootstrap=False, criterion='mse', max_depth=5,
#           max_features='sqrt', max_leaf_nodes=None,
#           min_impurity_split=1e-07, min_samples_leaf=10,
#           min_samples_split=2, min_weight_fraction_leaf=0.0,
#           n_estimators=100, n_jobs=-1, oob_score=False, random_state=17,
#           verbose=0, warm_start=False)

# %%
pred = etr.predict(X_train[features1])
twosigmafunc.R_score(pred, y_train)
# Out:
# 0.039001450701881948

# %%
pred = etr.predict(X_test[features1])
twosigmafunc.R_score(pred, y_test)
# Out:
# 0.017531833530225232

# %%
imp = pd.DataFrame({'feature':features1, 'important':etr.feature_importances_}).sort_values('important', ascending=False)

# %%
features1 = list(imp.loc[imp.important > 0.001].feature)
len(features1)
# Out:
# 174

# %%
etr = ExtraTreesRegressor(n_jobs=-1,n_estimators=100, max_depth=5, max_features=0.5, min_samples_leaf=10,
                          random_state=17, verbose=0)
etr.fit(X_train[features1], y_train)
# Out:
# ExtraTreesRegressor(bootstrap=False, criterion='mse', max_depth=5,
#           max_features=0.5, max_leaf_nodes=None, min_impurity_split=1e-07,
#           min_samples_leaf=10, min_samples_split=2,
#           min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#           oob_score=False, random_state=17, verbose=0, warm_start=False)

# %%
pred = etr.predict(X_train[features1])
twosigmafunc.R_score(pred, y_train)
# Out:
# 0.057029250729028459

# %%
pred = etr.predict(X_test[features1])
twosigmafunc.R_score(pred, y_test)
# Out:
# 0.025862180690397269

# %%
imp = pd.DataFrame({'feature':features1, 'important':etr.feature_importances_}).sort_values('important', ascending=False)

# %%
features1 = list(imp.loc[imp.important > 0.001].feature)
len(features1)
# Out:
# 119

# %%
etr.fit(X_train[features1], y_train)
# Out:
# ExtraTreesRegressor(bootstrap=False, criterion='mse', max_depth=5,
#           max_features=0.5, max_leaf_nodes=None, min_impurity_split=1e-07,
#           min_samples_leaf=10, min_samples_split=2,
#           min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#           oob_score=False, random_state=17, verbose=0, warm_start=False)

# %%
pred = etr.predict(X_train[features1])
twosigmafunc.R_score(pred, y_train)
# Out:
# 0.057149051908043001

# %%
pred = etr.predict(X_test[features1])
twosigmafunc.R_score(pred, y_test)
# Out:
# 0.026110956456432254

# %%
imp = pd.DataFrame({'feature':features1, 'important':etr.feature_importances_}).sort_values('important', ascending=False)

# %%
imp
# Out:
#                  feature  important
# 0                 y_past   0.056752
# 2                 tec123   0.049693
# 1               tec20-30   0.045011
# 3           technical_30   0.044728
# 4           technical_11   0.043691
# 6           technical_43   0.041693
# 7         fundamental_11   0.035513
# 5            tec123_past   0.034407
# 8           technical_20   0.031330
# 9      technical_11_diff   0.025702
# 12           technical_2   0.025679
# 10     technical_43_diff   0.022213
# 14     technical_21_diff   0.020142
# 21      technical_6_diff   0.018665
# 13      technical_2_diff   0.017975
# 16     technical_30_diff   0.015965
# 23          technical_17   0.013280
# 11           technical_6   0.013069
# 17      technical_44_nan   0.013055
# 18           technical_7   0.013018
# 20         fundamental_8   0.011731
# 22          technical_21   0.011103
# 15    fundamental_25_nan   0.010762
# 29       technical_0_nan   0.010576
# 41    fundamental_27_nan   0.010268
# 30      technical_24_nan   0.010211
# 26        fundamental_53   0.010187
# 32          technical_40   0.009925
# 47               t22_0.5   0.009822
# 38       technical_9_nan   0.009620
# ..                   ...        ...
# 102            derived_0   0.002081
# 111       fundamental_31   0.001935
# 72     technical_38_diff   0.001911
# 62    fundamental_47_nan   0.001833
# 78    fundamental_21_nan   0.001790
# 112   fundamental_54_nan   0.001755
# 68         derived_3_nan   0.001721
# 93        fundamental_54   0.001721
# 91        fundamental_13   0.001695
# 117        fundamental_3   0.001598
# 107              t34_0.5   0.001431
# 85     technical_24_diff   0.001363
# 115    technical_41_diff   0.001304
# 95          technical_28   0.001202
# 84         fundamental_7   0.001153
# 103    technical_13_diff   0.001051
# 71         derived_0_nan   0.001031
# 106   fundamental_7_diff   0.001013
# 118     technical_20_nan   0.000920
# 116      technical_3_nan   0.000867
# 105    fundamental_1_nan   0.000846
# 104         technical_42   0.000839
# 113   fundamental_63_nan   0.000809
# 108     technical_29_nan   0.000732
# 89             derived_1   0.000677
# 114   fundamental_31_nan   0.000601
# 101       fundamental_29   0.000557
# 87   fundamental_53_diff   0.000513
# 69      technical_39_nan   0.000373
# 94        fundamental_39   0.000228
#
# [119 rows x 2 columns]

# %%
for col in list(t22_dummy.columns) + list(t34_dummy.columns):
    print(imp[imp.feature==col])
# Out:
# Empty DataFrame
# Columns: [feature, important]
# Index: []
# Empty DataFrame
# Columns: [feature, important]
# Index: []
#     feature  important
# 47  t22_0.5   0.009822
#      feature  important
# 51  t34_-0.5   0.007906
# Empty DataFrame
# Columns: [feature, important]
# Index: []
#      feature  important
# 107  t34_0.5   0.001431

# %%
features1 = list(imp.loc[imp.important > 0.002].feature)
len(features1)
# Out:
# 90

# %%
etr.fit(X_train[features1], y_train)
# Out:
# ExtraTreesRegressor(bootstrap=False, criterion='mse', max_depth=5,
#           max_features=0.5, max_leaf_nodes=None, min_impurity_split=1e-07,
#           min_samples_leaf=10, min_samples_split=2,
#           min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#           oob_score=False, random_state=17, verbose=0, warm_start=False)

# %%
pred = etr.predict(X_train[features1])
twosigmafunc.R_score(pred, y_train)
# Out:
# 0.057408487244495196

# %%
pred = etr.predict(X_test[features1])
twosigmafunc.R_score(pred, y_test)
# Out:
# 0.026549861209870653

# %%
min_impurities = [1e-7, 1e-6, 1e-5]
for split in min_impurities:
    print("\nmin_imp:", split)
    etr = ExtraTreesRegressor(n_jobs=-1,n_estimators=100, max_depth=5, max_features=0.5, min_samples_leaf=10,
                          random_state=17, min_impurity_split=split, verbose=0)
    etr.fit(X_train[features1], y_train)
    pred = etr.predict(X_train[features1])
    print("train r_score:", twosigmafunc.R_score(pred, y_train))
    pred = etr.predict(X_test[features1])
    print("test r_score:", twosigmafunc.R_score(pred, y_test))
# Out:
# min_imp: 1e-07
# train r_score: 0.0574084872445
# test r_score: 0.0265498612099
#
# min_imp: 1e-06
# train r_score: 0.0574084872445
# test r_score: 0.0265498612099
#
# min_imp: 1e-05
# train r_score: 0.0574084872445
# test r_score: 0.0265498612099

# %%
depths = [3, 6, 10]
for depth in depths:
    print("\nmax_depth:", depth)
    etr = ExtraTreesRegressor(n_jobs=-1,n_estimators=100, max_depth=depth, max_features=0.5, min_samples_leaf=10,
                          random_state=17, min_impurity_split=1e-6, verbose=0)
    etr.fit(X_train[features1], y_train)
    pred = etr.predict(X_train[features1])
    print("train r_score:", twosigmafunc.R_score(pred, y_train))
    pred = etr.predict(X_test[features1])
    print("test r_score:", twosigmafunc.R_score(pred, y_test))
# Out:
# max_depth: 3
# train r_score: 0.0350788669252
# test r_score: 0.0204991760254
#
# max_depth: 6
# train r_score: 0.0691055516104
# test r_score: 0.029090089532
#
# max_depth: 10
# train r_score: 0.126810120496
# test r_score: 0.0335086324267

# %%
samples = [10, 30, 50]
for sample in samples:
    print("\nmin_samples:", sample)
    etr = ExtraTreesRegressor(n_jobs=-1,n_estimators=100, max_depth=6, max_features=0.5, min_samples_leaf=sample,
                          random_state=17, min_impurity_split=1e-6, verbose=0)
    etr.fit(X_train[features1], y_train)
    pred = etr.predict(X_train[features1])
    print("train r_score:", twosigmafunc.R_score(pred, y_train))
    pred = etr.predict(X_test[features1])
    print("test r_score:", twosigmafunc.R_score(pred, y_test))
# Out:
# min_samples: 10
# train r_score: 0.0691055516104
# test r_score: 0.029090089532
#
# min_samples: 30
# train r_score: 0.0678485822473
# test r_score: 0.0303077151944
#
# min_samples: 50
# train r_score: 0.0650103716902
# test r_score: 0.0304655350213

# %%
features = [0.6, 0.75, 1.0]
for feature in features:
    print("\nmax_features:", feature)
    etr = ExtraTreesRegressor(n_jobs=-1,n_estimators=100, max_depth=6, max_features=feature, min_samples_leaf=sample,
                          random_state=17, min_impurity_split=1e-6, verbose=0)
    etr.fit(X_train[features1], y_train)
    pred = etr.predict(X_train[features1])
    print("train r_score:", twosigmafunc.R_score(pred, y_train))
    pred = etr.predict(X_test[features1])
    print("test r_score:", twosigmafunc.R_score(pred, y_test))
# Out:
# max_features: 0.6
# train r_score: 0.0670824348793
# test r_score: 0.0297397428562
#
# max_features: 0.75
# train r_score: 0.0682134865686
# test r_score: 0.0310089972195
#
# max_features: 1.0
# train r_score: 0.0695938583222
# test r_score: 0.0311505577685

# %%
depths = [5, 7, None]
samples = [55, 70]
features = [0.8]
best_param = {}
best_score = -99
for depth in depths:
    for sample in samples:
        for feature in features:
            print('max_depth:', depth, 'min_samples_leaf:', sample, 'max_features:', feature)
            etr = ExtraTreesRegressor(n_jobs=-1,n_estimators=100, max_depth=depth, max_features=feature, min_samples_leaf=sample,
                          random_state=17, min_impurity_split=1e-6, verbose=0)
            etr.fit(X_train[features1], y_train)
            pred = etr.predict(X_train[features1])
            print("train r_score:", twosigmafunc.R_score(pred, y_train))
            pred = etr.predict(X_test[features1])
            r = twosigmafunc.R_score(pred, y_test)
            print("test r_score:", r)
            if r > best_score:
                best_param = {'samples':sample, 'depth':depth, 'features':feature}
print(best_param)
# Out:
# max_depth: 5 min_samples_leaf: 55 max_features: 0.8
# train r_score: 0.0571148335089
# test r_score: 0.0284461617142
# max_depth: 5 min_samples_leaf: 70 max_features: 0.8
# train r_score: 0.0566318710383
# test r_score: 0.0284634151628
# max_depth: 7 min_samples_leaf: 55 max_features: 0.8
# train r_score: 0.0790944866718
# test r_score: 0.0334907548645
# max_depth: 7 min_samples_leaf: 70 max_features: 0.8
# train r_score: 0.0774035865749
# test r_score: 0.0328106626575
# max_depth: None min_samples_leaf: 55 max_features: 0.8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-119-287b82e12d55> in <module>()
#      10             etr = ExtraTreesRegressor(n_jobs=-1,n_estimators=100, max_depth=depth, max_features=feature, min_samples_leaf=sample,
#      11                           random_state=17, min_impurity_split=1e-6, verbose=0)
# ---> 12             etr.fit(X_train[features1], y_train)
#      13             pred = etr.predict(X_train[features1])
#      14             print("train r_score:", twosigmafunc.R_score(pred, y_train))
#
# /usr/local/lib/python3.4/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     324                     t, self, X, y, sample_weight, i, len(trees),
#     325                     verbose=self.verbose, class_weight=self.class_weight)
# --> 326                 for i, t in enumerate(trees))
#     327
#     328             # Collect newly grown trees
#
# /usr/local/lib/python3.4/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     766                 # consumption.
#     767                 self._iterating = False
# --> 768             self.retrieve()
#     769             # Make sure that we get a last message telling us we are done
#     770             elapsed_time = time.time() - self._start_time
#
# /usr/local/lib/python3.4/site-packages/sklearn/externals/joblib/parallel.py in retrieve(self)
#     717                     ensure_ready = self._managed_backend
#     718                     backend.abort_everything(ensure_ready=ensure_ready)
# --> 719                 raise exception
#     720
#     721     def __call__(self, iterable):
#
# /usr/local/lib/python3.4/site-packages/sklearn/externals/joblib/parallel.py in retrieve(self)
#     680                 # check if timeout supported in backend future implementation
#     681                 if 'timeout' in getfullargspec(job.get).args:
# --> 682                     self._output.extend(job.get(timeout=self.timeout))
#     683                 else:
#     684                     self._output.extend(job.get())
#
# /usr/local/Cellar/python3/3.4.3_2/Frameworks/Python.framework/Versions/3.4/lib/python3.4/multiprocessing/pool.py in get(self, timeout)
#     591
#     592     def get(self, timeout=None):
# --> 593         self.wait(timeout)
#     594         if not self.ready():
#     595             raise TimeoutError
#
# /usr/local/Cellar/python3/3.4.3_2/Frameworks/Python.framework/Versions/3.4/lib/python3.4/multiprocessing/pool.py in wait(self, timeout)
#     588
#     589     def wait(self, timeout=None):
# --> 590         self._event.wait(timeout)
#     591
#     592     def get(self, timeout=None):
#
# /usr/local/Cellar/python3/3.4.3_2/Frameworks/Python.framework/Versions/3.4/lib/python3.4/threading.py in wait(self, timeout)
#     551             signaled = self._flag
#     552             if not signaled:
# --> 553                 signaled = self._cond.wait(timeout)
#     554             return signaled
#     555         finally:
#
# /usr/local/Cellar/python3/3.4.3_2/Frameworks/Python.framework/Versions/3.4/lib/python3.4/threading.py in wait(self, timeout)
#     288         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     289             if timeout is None:
# --> 290                 waiter.acquire()
#     291                 gotit = True
#     292             else:
#
# KeyboardInterrupt:

# %%
features1
# Out:
# ['y_past',
#  'tec123',
#  'tec20-30',
#  'technical_30',
#  'technical_11',
#  'technical_43',
#  'fundamental_11',
#  'tec123_past',
#  'technical_20',
#  'technical_11_diff',
#  'technical_2',
#  'technical_43_diff',
#  'technical_21_diff',
#  'technical_6_diff',
#  'technical_2_diff',
#  'technical_30_diff',
#  'technical_17',
#  'technical_6',
#  'technical_44_nan',
#  'technical_7',
#  'fundamental_8',
#  'technical_21',
#  'fundamental_25_nan',
#  'technical_0_nan',
#  'fundamental_27_nan',
#  'technical_24_nan',
#  'fundamental_53',
#  'technical_40',
#  't22_0.5',
#  'technical_9_nan',
#  'technical_14',
#  'technical_17_diff',
#  'technical_20_diff',
#  'technical_19',
#  'technical_28_nan',
#  'technical_37_nan',
#  'technical_12_nan',
#  'technical_32_nan',
#  't34_-0.5',
#  'technical_25_nan',
#  'fundamental_21',
#  'technical_14_diff',
#  'fundamental_33_nan',
#  'fundamental_18',
#  'technical_38_nan',
#  'technical_35',
#  'derived_1_nan',
#  'fundamental_33',
#  'fundamental_48',
#  'technical_31_nan',
#  'technical_19_diff',
#  'fundamental_50',
#  'technical_27',
#  'null_count',
#  'fundamental_58',
#  'technical_10',
#  'fundamental_34',
#  'fundamental_2',
#  'technical_12',
#  'technical_35_diff',
#  'technical_42_nan',
#  'technical_41',
#  'fundamental_23',
#  'technical_36',
#  'technical_29',
#  'fundamental_41_nan',
#  'fundamental_0_nan',
#  'technical_29_diff',
#  'fundamental_42_nan',
#  'technical_40_diff',
#  'fundamental_5_nan',
#  'fundamental_53_nan',
#  'fundamental_15',
#  'fundamental_56',
#  'technical_5',
#  'fundamental_17_nan',
#  'derived_2_nan',
#  'technical_5_nan',
#  'fundamental_59',
#  'fundamental_0',
#  'fundamental_40',
#  'fundamental_41',
#  'technical_44',
#  'fundamental_44',
#  'fundamental_36',
#  'fundamental_42',
#  'technical_1_nan',
#  'fundamental_55',
#  'technical_18_nan',
#  'derived_0']

# %% [markdown]
# # Hardcoding...

# %%
import zlib
import pickle
def zdumps(obj):
    return zlib.compress(pickle.dumps(obj,pickle.HIGHEST_PROTOCOL),9)

def zloads(zstr):
    return pickle.loads(zlib.decompress(zstr))

# %%
etr = ExtraTreesRegressor(n_jobs=-1,n_estimators=128, max_depth=5, max_features=0.8, min_samples_leaf=50,
                          random_state=17, verbose=0)
etr.fit(train[features1], target)
# Out:
# ExtraTreesRegressor(bootstrap=False, criterion='mse', max_depth=5,
#           max_features=0.8, max_leaf_nodes=None, min_impurity_split=1e-07,
#           min_samples_leaf=50, min_samples_split=2,
#           min_weight_fraction_leaf=0.0, n_estimators=128, n_jobs=-1,
#           oob_score=False, random_state=17, verbose=0, warm_start=False)

# %%
train = pd.concat([X_train, X_test], axis=0)

# %%
target = pd.concat([y_train, y_test], axis=0)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1710756 entries, 131062 to 1710755
# Columns: 333 entries, derived_0 to tec123_past
# dtypes: float32(218), int64(109), uint8(6)
# memory usage: 2.8 GB

# %%
etr_hard = zdumps(etr)

# %%
try:
    with open('etr_hard.hard', 'wb') as hard_f:
        hard_f.write(etr_hard)
except IOError as err:
    raise err

# %%
etr_hard
# Out:
# b'x\xda\xdc\xbdy<\x95\xdd\xf77\xae\tE\xa5Y\xa8P!\x19#3\xeb\x08!2\xcf\x999\x1c\xf3<$D\x08%ITJR\xa4AD\t\x95lE\xa5\xa4"\xa59\x8a\xd2$)M\xa4G\xf7\xc7\xd5\xd9\xc7u\xdf\xcf\xf5\xb9\x7f\xcf\xeb\xf7\xc7\xf7{\xfe\xe8:b]{Z{\xed\xb5\xde\xfb\xbd\xd7\x8e\x9b\x98\xcd\x984\x8e\xed\xf7\'m^\x88\x8f/\xdd%\xd8_\x8a\xee\x1fB\xf7s\xf5\xa5Ky\x04\x04\xd3CB\xb3\xd2f\xe9D\x86\x06\xbbX\x04\xd3\xe9!ft\xcf\x91\xff\x0b\t\x08\xce\xda\x99\xb5,&+3+&K,\x8d\xd7\xcf\xcb\xdf)\x82\xee\xe5\xc9\x08u\xf2\x08vq\x0b\xf5\n\xf0w\x1ay\x97G\x96.\xdb\xe8\'\x8d\xdd\xdf\xc9;\xc05$k\xcd\xaf\x91O\x1a\xb7\x9fK\xa4\x93\x07\xdd%4l\xe4mY\